# %% [markdown]
# ## Map Reduce group project

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import math
from sklearn import tree
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVR
from sklearn.svm import SVC
# Pipeline
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
# Cost Functions
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# Preprocessing
from sklearn.impute import SimpleImputer

# Scalers
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MinMaxScaler

# Feature Engineering
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
# This is for regression
from sklearn.tree import DecisionTreeRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# This is for classification
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
covid = pd.read_csv("CovidData.csv")

# %%
covid.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
# drop missing data  
covid.drop(covid[(covid['USMER']==97) |(covid['USMER']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['MEDICAL_UNIT']==97) |(covid['MEDICAL_UNIT']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['SEX']==97) |(covid['SEX']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['PATIENT_TYPE']==97) |(covid['PATIENT_TYPE']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['INTUBED']==97) |(covid['INTUBED']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['PNEUMONIA']==97) |(covid['PNEUMONIA']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['PREGNANT']==97) |(covid['PREGNANT']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['DIABETES']==97) |(covid['DIABETES']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['COPD']==97) |(covid['COPD']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['ASTHMA']==97) |(covid['ASTHMA']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['HIPERTENSION']==97) |(covid['HIPERTENSION']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['INMSUPR']==97) |(covid['INMSUPR']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['CARDIOVASCULAR']==97) |(covid['CARDIOVASCULAR']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['OBESITY']==97) |(covid['OBESITY']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['RENAL_CHRONIC']==97) |(covid['RENAL_CHRONIC']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['TOBACCO']==97) |(covid['TOBACCO']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['CLASIFFICATION_FINAL']==97) |(covid['CLASIFFICATION_FINAL']== 99)].index, axis=0,inplace=True)
covid.drop(covid[(covid['ICU']==97) |(covid['ICU']== 99)].index, axis=0,inplace=True)
covid
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 5            2             1    1             2  9999-99-99        2
# 8            2             1    1             2  9999-99-99        2
# 9            2             1    1             2  9999-99-99        2
# 16           2             1    1             2  9999-99-99        2
# 56           2             1    1             2  9999-99-99        1
# ...        ...           ...  ...           ...         ...      ...
# 1048535      1            13    1             2  9999-99-99        2
# 1048553      2            13    1             2  9999-99-99        2
# 1048554      2            13    1             2  9999-99-99        2
# 1048567      1            13    1             2  9999-99-99        2
# 1048569      1            13    1             2  9999-99-99        2
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 5                1   40         2         2  ...       2        2
# ...

# %%
covid["DATE_DIED"].unique()
# Out:
# array(['9999-99-99', '08/05/2020', '07/03/2020', '27/03/2020',
#        '05/04/2020', '07/04/2020', '08/04/2020', '10/04/2020',
#        '11/04/2020', '12/04/2020', '14/04/2020', '15/04/2020',
#        '17/04/2020', '20/04/2020', '22/04/2020', '24/04/2020',
#        '25/04/2020', '26/04/2020', '29/04/2020', '30/04/2020',
#        '01/05/2020', '04/05/2020', '05/05/2020', '06/05/2020',
#        '07/05/2020', '09/05/2020', '10/05/2020', '11/05/2020',
#        '12/05/2020', '13/05/2020', '14/05/2020', '15/05/2020',
#        '16/05/2020', '17/05/2020', '18/05/2020', '19/05/2020',
#        '20/05/2020', '21/05/2020', '22/05/2020', '23/05/2020',
#        '24/05/2020', '25/05/2020', '26/05/2020', '27/05/2020',
#        '28/05/2020', '29/05/2020', '30/05/2020', '31/05/2020',
#        '01/06/2020', '02/06/2020', '03/06/2020', '04/06/2020',
#        '05/06/2020', '06/06/2020', '07/06/2020', '08/06/2020',
#        '09/06/2020', '10/06/2020', '11/06/2020', '12/06/2020',
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78175 entries, 5 to 1048569
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   USMER                 78175 non-null  int64
#  1   MEDICAL_UNIT          78175 non-null  int64
#  2   SEX                   78175 non-null  int64
#  3   PATIENT_TYPE          78175 non-null  int64
#  4   DATE_DIED             78175 non-null  object
#  5   INTUBED               78175 non-null  int64
#  6   PNEUMONIA             78175 non-null  int64
#  7   AGE                   78175 non-null  int64
#  8   PREGNANT              78175 non-null  int64
#  9   DIABETES              78175 non-null  int64
#  10  COPD                  78175 non-null  int64
#  11  ASTHMA                78175 non-null  int64
#  12  INMSUPR               78175 non-null  int64
#  13  HIPERTENSION          78175 non-null  int64
#  14  OTHER_DISEASE         78175 non-null  int64
# ...

# %%
np.savetxt(r'C:/Users/DELL/OneDrive/Desktop/Lina/Big data & AI bootcamp/file.txt', covid.DATE_DIED, fmt='%s')

# %% [markdown]
# ### Map reduce

# %%
# %%file wordcount.py

from mrjob.job import MRJob 

class MRdateCount(MRJob):
    
   
    def mapper(self, _, date):
         
        yield (date, 1)

   
    def reducer(self, key, values):
        yield (key, sum(values))
        
if __name__ == "__main__":
    MRdateCount.run()
# Out:
# Overwriting wordcount.py

# %%
# run the code as a terminal command
# !python wordcount.py file.txt
# Out:
# "01\/02\/2020"	1
# "01\/02\/2021"	1
# "01\/03\/2020"	1
# "01\/04\/2020"	16
# "01\/04\/2021"	1
# "01\/05\/2020"	177
# "01\/05\/2021"	8
# "01\/06\/2020"	254
# "01\/07\/2020"	301
# "01\/08\/2020"	52
# "02\/03\/2020"	1
# "02\/04\/2020"	20
# "02\/05\/2020"	167
# "02\/05\/2021"	9
# "02\/06\/2020"	249
# "02\/07\/2020"	251
# "02\/08\/2020"	32
# "02\/09\/2020"	3
# "03\/02\/2020"	1
# "03\/02\/2021"	3
# "03\/03\/2020"	1
# "03\/04\/2020"	25
# "03\/05\/2020"	141
# "03\/06\/2020"	274
# "03\/07\/2020"	249
# "03\/08\/2020"	32
# "03\/09\/2020"	3
# "04\/02\/2020"	2
# "04\/03\/2020"	3
# "04\/04\/2020"	31
# "04\/05\/2020"	189
# "04\/06\/2020"	251
# "04\/07\/2020"	295
# "04\/08\/2020"	23
# "04\/09\/2020"	2
# "04\/11\/2020"	1
# "05\/02\/2020"	1
# "05\/02\/2021"	1
# "05\/03\/2020"	4
# "05\/04\/2020"	26
# "05\/05\/2020"	180
# "05\/06\/2020"	225
# "05\/07\/2020"	307
# "05\/08\/2020"	23
# "05\/09\/2020"	6
# "05\/10\/2020"	1
# "06\/01\/2021"	1
# "06\/02\/2021"	1
# "06\/03\/2020"	4
# "06\/04\/2020"	35
# ...

# %%
count_alive = len(covid[covid['DATE_DIED'].map(lambda x : x=='9999-99-99')])
count_dead = len(covid[covid['DATE_DIED'].map(lambda x : x!='9999-99-99')])
print(count_alive)
print(count_dead)
# Out:
# 53871
# 24304
